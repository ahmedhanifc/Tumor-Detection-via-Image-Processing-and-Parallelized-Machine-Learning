# %%
import pandas as pd

# %%
model_perforamnce = pd.read_excel("./data/machine_learning_performance/model_performance.xlsx")

# %%
model_perforamnce.sort_values(by = ["accuracy"], ascending= False)
# Out:
#            model_name                                   model_parameters  \
# 8        RandomForest  {'n_estimators': 10, 'max_features': 'log2', '...
# 38       RandomForest  {'n_estimators': 100, 'max_features': 'log2', ...
# 58       RandomForest  {'n_estimators': 200, 'max_features': None, 'm...
# 122  GradientBoosting  {'n_estimators': 100, 'learning_rate': 0.01, '...
# 92   GradientBoosting  {'n_estimators': 10, 'learning_rate': 0.1, 'ma...
# ..                ...                                                ...
# 170               SVC      {'C': 0.1, 'kernel': 'rbf', 'gamma': 'scale'}
# 172               SVC       {'C': 0.1, 'kernel': 'rbf', 'gamma': 'auto'}
# 176               SVC   {'C': 0.1, 'kernel': 'sigmoid', 'gamma': 'auto'}
# 190               SVC    {'C': 10, 'kernel': 'sigmoid', 'gamma': 'auto'}
# 200               SVC   {'C': 100, 'kernel': 'sigmoid', 'gamma': 'auto'}
#
#      accuracy  precision    recall  f1_score     confusion_matrix
# ...
